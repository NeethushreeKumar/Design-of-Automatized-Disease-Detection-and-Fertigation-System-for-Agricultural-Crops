# %%
#include <SoftwareSerial.h>

#define BLYNK_TEMPLATE_ID "TMPL3UfQQ45LS"
#define BLYNK_TEMPLATE_NAME "PROJECT"
#define BLYNK_AUTH_TOKEN "2ohxvar1NKLD-tXQPwnhgzeFXKIemhH0"

#define BLYNK_PRINT Serial
#include <ESP8266WiFi.h>
#include <BlynkSimpleEsp8266.h>

int rel1=D1;
int rel2=D2;
int rel3=D3;
int rel4=D4;

int val1 = 0;
int val2 = 0;
int val3 = 0;
int val4 = 0;
char auth[] = BLYNK_AUTH_TOKEN;

char ssid[] = "abcd";  // type your wifi name
char pass[] = "123456789";  // type your wifi password

 BLYNK_WRITE(V0){
     val1 = param.asInt();
     Serial.print("RELAY1 ");
    Serial.println(val1);
    digitalWrite(rel1,LOW);
  }

 BLYNK_WRITE(V1){

    val2 = param.asInt();
     Serial.print("RELAY2 ");
    Serial.println(val2);
    digitalWrite(rel2,LOW);
  }

 BLYNK_WRITE(V2){

    val3 = param.asInt();
     Serial.print("Slider value: ");
    Serial.println(val3);
    digitalWrite(rel3,LOW);
  }

   BLYNK_WRITE(V3){

    val4 = param.asInt();
     Serial.print("Slider value: ");
    Serial.println(val4);
    digitalWrite(rel4,LOW);
  }

void setup() {
   Serial.begin(115200);
   Blynk.begin(auth, ssid, pass);

     pinMode(rel1,OUTPUT);

   pinMode(rel2,OUTPUT);

   pinMode(rel3,OUTPUT);

   pinMode(rel4,OUTPUT);

   digitalWrite(rel1,HIGH);
   digitalWrite(rel2,HIGH);
   digitalWrite(rel3,HIGH);
   digitalWrite(rel4,HIGH);
  // put your setup code here, to run once:

}

void loop() {
 Blynk.run();

}

# %%
#include <SoftwareSerial.h>

#define BLYNK_TEMPLATE_ID "TMPL3UfQQ45LS"
#define BLYNK_TEMPLATE_NAME "PROJECT"
#define BLYNK_AUTH_TOKEN "2ohxvar1NKLD-tXQPwnhgzeFXKIemhH0"

#define BLYNK_PRINT Serial
#include <ESP8266WiFi.h>
#include <BlynkSimpleEsp8266.h>

int rel1=D1;
int rel2=D2;
int rel3=D3;
int rel4=D4;

int val1 = 0;
int val2 = 0;
int val3 = 0;
int val4 = 0;
char auth[] = BLYNK_AUTH_TOKEN;

char ssid[] = "abcd";  // type your wifi name
char pass[] = "123456789";  // type your wifi password

 BLYNK_WRITE(V0){

    val1 = param.asInt();
     Serial.print("RELAY1 ");
    Serial.println(val1);
    if(val1==1){
  digitalWrite(rel1,LOW);
    }
    else{

    digitalWrite(rel1,HIGH);
    }

     }

 BLYNK_WRITE(V1){

    val2 = param.asInt();
     Serial.print("RELAY2 ");
    Serial.println(val2);
     if(val2==1){
  digitalWrite(rel2,LOW);
    }
    else{

    digitalWrite(rel2,HIGH);
    }
  }

 BLYNK_WRITE(V2){

    val3 = param.asInt();
     Serial.print("Slider value: ");
    Serial.println(val3);
    if(val3==1){
  digitalWrite(rel3,LOW);
    }
    else{

    digitalWrite(rel3,HIGH);
    }
  }

   BLYNK_WRITE(V3){
         val4 = param.asInt();
     Serial.print("Slider value: ");
    Serial.println(val4);
     if(val4==1){
  digitalWrite(rel4,LOW);
    }
    else{

    digitalWrite(rel4,HIGH);
    }
  }

void setup() {
   Serial.begin(115200);
   Blynk.begin(auth, ssid, pass);

   pinMode(rel1,OUTPUT);

   pinMode(rel2,OUTPUT);

   pinMode(rel3,OUTPUT);

   pinMode(rel4,OUTPUT);

   digitalWrite(rel1,HIGH);
   digitalWrite(rel2,HIGH);
   digitalWrite(rel3,HIGH);
   digitalWrite(rel4,HIGH);
  // put your setup code here, to run once:

}

void loop() {
 Blynk.run();
 }
